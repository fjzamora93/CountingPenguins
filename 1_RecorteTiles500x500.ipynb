# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import utils.img_fun as img_fun
import rasterio
import numpy as np
from rasterio.transform import from_origin
from rasterio.windows import Window

# %% [markdown]
# ### Cargamos la imagen y obtenemos las variables clave (ancho, alto, esquinas)
#
# Rasterio es la liberería que permitirá que las imágenes conserven los metadatos y que estén georeferenciadas aún después de procesarlas y recortarlas.

# %%
# path  = '/content/drive/My Drive/doctorado_albert/conteo_pinguinos/'
# image_name = "orthomosaic_all_big.tif"

NUM_TILE = 22

if os.path.exists('/content/drive/My Drive/doctorado_albert/conteo_pinguinos/'):
    path  = '/content/drive/My Drive/doctorado_albert/conteo_pinguinos/'
else:
    path = 'G:\\.shortcut-targets-by-id\\1pYgV5EIk4-LapLNhlCwpQaDAzuqNffXG\\doctorado_albert\\conteo_pinguinos'

image_name = f"recortes/recorte_{NUM_TILE}.tif"
tiff_file = os.path.join(path, image_name)


# Sacamos un diccionario con toda la información de la imagen
img_info = img_fun.get_img_info(tiff_file)

WIDTH = img_info["width"]
HEIGHT = img_info["height"]
TOP_LEFT = img_info["top_left"]
BOTTOM_RIGHT = img_info["bottom_right"]
min_x, max_y = img_info['top_left']
max_x, min_y = img_info['bottom_right']
# Out:
# Metadatos de la imagen:
# driver: GTiff
# dtype: uint8
# nodata: None
# width: 10195
# height: 11420
# count: 4
# crs: EPSG:4326
# transform: | 0.00, 0.00,-59.24|
# | 0.00,-0.00,-62.29|
# | 0.00, 0.00, 1.00|
#
# Información adicional:
# Ancho y alto de la imagen: 10195  x  11420
# Sistema de coordenadas: EPSG:4326
# Transformación: | 0.00, 0.00,-59.24|
# | 0.00,-0.00,-62.29|
# | 0.00, 0.00, 1.00|
# Coordenadas de las esquinas de la imagen:
# TOP LEFT: (-59.236389267356785, -62.290013442834734)
# BOTTOM RIGHT: (-59.231134009926784, -62.29275364899473)

# %% [markdown]
# ## Recorte de los tiles y carpeta de salida
#
# 1. Se define en cuánto se quiere recortar (en nuestro caso 20 filas y 20 columnas).
# 2. Se descartan todos los tiles que tengan una alta proporción de píxeles blanco o negros (mnás del 50%)
# 3. Acto seguido se procede al recorte y se envía a la carpeta de OUPUT_DIR.

# %%
#Directorio de salida
OUTPUT_DIR = os.path.join('cut_tiles', f'tiles_500x500_{NUM_TILE}')
os.makedirs(OUTPUT_DIR, exist_ok=True)
print(f"Output directory: {OUTPUT_DIR}")

# Definición del recorte
ROWS, COLS = 20, 20
tile_width = WIDTH // COLS
tile_height = HEIGHT // ROWS

# Abrir el TIFF original con rasterio
with rasterio.open(tiff_file) as src:
    for i in range(ROWS):
        print("Fila nº ", i)
        for j in range(COLS):
            left = j * tile_width
            upper = i * tile_height
            
            # Definir ventana de recorte
            window = Window(left, upper, tile_width, tile_height)
            
            # Leer el recorte
            cropped_image = src.read(window=window)

            # Identificar píxeles negros (000000)
            is_black = np.all(cropped_image == 0, axis=0)
            
            # Identificar píxeles blancos (FFFFFF)
            is_white = np.all(cropped_image == 255, axis=0)
            
            # Identificar píxeles vacíos o transparentes (suponiendo valor 0 en el canal de alfa o nodata)
            if "nodata" in src.profile:
                nodata_value = src.profile["nodata"]
                is_empty = np.any(cropped_image == nodata_value, axis=0)
            else:
                # Si hay un canal alfa, considera valores 0 como transparentes
                is_empty = cropped_image.shape[0] > 3 and np.all(cropped_image[-1] == 0, axis=0)

            # Calcular proporciones de píxeles negros, blancos y vacíos
            num_pixels = cropped_image.shape[1] * cropped_image.shape[2]  # Total de píxeles
            black_ratio = np.sum(is_black) / num_pixels
            white_ratio = np.sum(is_white) / num_pixels
            empty_ratio = np.sum(is_empty) / num_pixels

            # Guardar solo si todos los umbrales se cumplen
            if black_ratio <= 0.5 and white_ratio <= 0.1 and empty_ratio <= 0.1:
                # Crear los metadatos del recorte
                cropped_meta = src.meta.copy()
                cropped_meta.update({
                    "height": tile_height,
                    "width": tile_width,
                    "transform": rasterio.windows.transform(window, src.transform)
                })
                
                # Guardar la imagen recortada con georreferenciación
                output_path = f"{OUTPUT_DIR}/tile_{NUM_TILE}_subrecorte_{i * COLS + j + 1}.tiff"
                with rasterio.open(output_path, 'w', **cropped_meta) as dst:
                    dst.write(cropped_image)
                print(f"Guardado recorte {i * COLS + j + 1} en {output_path}")
            else:
                print(f"Recorte {i * COLS + j + 1} descartado por exceso de píxeles negros, blancos o vacíos")
# Out:
# Output directory: cut_tiles\tiles_500x500_22
# Fila nº  0
# Recorte 1 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 2 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 3 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 4 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 5 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 6 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 7 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 8 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 9 descartado por exceso de píxeles negros, blancos o vacíos
# Guardado recorte 10 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_10.tiff
# Guardado recorte 11 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_11.tiff
# Guardado recorte 12 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_12.tiff
# Guardado recorte 13 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_13.tiff
# Guardado recorte 14 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_14.tiff
# Guardado recorte 15 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_15.tiff
# Guardado recorte 16 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_16.tiff
# Guardado recorte 17 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_17.tiff
# Guardado recorte 18 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_18.tiff
# Guardado recorte 19 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_19.tiff
# Guardado recorte 20 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_20.tiff
# Fila nº  1
# Recorte 21 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 22 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 23 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 24 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 25 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 26 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 27 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 28 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 29 descartado por exceso de píxeles negros, blancos o vacíos
# Guardado recorte 30 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_30.tiff
# Guardado recorte 31 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_31.tiff
# Guardado recorte 32 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_32.tiff
# Guardado recorte 33 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_33.tiff
# Guardado recorte 34 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_34.tiff
# Guardado recorte 35 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_35.tiff
# Guardado recorte 36 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_36.tiff
# Guardado recorte 37 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_37.tiff
# Guardado recorte 38 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_38.tiff
# Guardado recorte 39 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_39.tiff
# Guardado recorte 40 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_40.tiff
# Fila nº  2
# Recorte 41 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 42 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 43 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 44 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 45 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 46 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 47 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 48 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 49 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 50 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 51 descartado por exceso de píxeles negros, blancos o vacíos
# Guardado recorte 52 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_52.tiff
# Guardado recorte 53 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_53.tiff
# Guardado recorte 54 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_54.tiff
# Guardado recorte 55 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_55.tiff
# Guardado recorte 56 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_56.tiff
# Guardado recorte 57 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_57.tiff
# Guardado recorte 58 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_58.tiff
# Guardado recorte 59 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_59.tiff
# Guardado recorte 60 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_60.tiff
# Fila nº  3
# Recorte 61 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 62 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 63 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 64 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 65 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 66 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 67 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 68 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 69 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 70 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 71 descartado por exceso de píxeles negros, blancos o vacíos
# Guardado recorte 72 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_72.tiff
# Guardado recorte 73 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_73.tiff
# Guardado recorte 74 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_74.tiff
# Guardado recorte 75 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_75.tiff
# Guardado recorte 76 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_76.tiff
# Guardado recorte 77 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_77.tiff
# Guardado recorte 78 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_78.tiff
# Guardado recorte 79 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_79.tiff
# Guardado recorte 80 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_80.tiff
# Fila nº  4
# Recorte 81 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 82 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 83 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 84 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 85 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 86 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 87 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 88 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 89 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 90 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 91 descartado por exceso de píxeles negros, blancos o vacíos
# Guardado recorte 92 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_92.tiff
# Guardado recorte 93 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_93.tiff
# Guardado recorte 94 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_94.tiff
# Guardado recorte 95 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_95.tiff
# Guardado recorte 96 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_96.tiff
# Guardado recorte 97 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_97.tiff
# Guardado recorte 98 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_98.tiff
# Guardado recorte 99 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_99.tiff
# Guardado recorte 100 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_100.tiff
# Fila nº  5
# Recorte 101 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 102 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 103 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 104 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 105 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 106 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 107 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 108 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 109 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 110 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 111 descartado por exceso de píxeles negros, blancos o vacíos
# Guardado recorte 112 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_112.tiff
# Guardado recorte 113 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_113.tiff
# Guardado recorte 114 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_114.tiff
# Guardado recorte 115 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_115.tiff
# Guardado recorte 116 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_116.tiff
# Guardado recorte 117 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_117.tiff
# Guardado recorte 118 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_118.tiff
# Guardado recorte 119 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_119.tiff
# Guardado recorte 120 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_120.tiff
# Fila nº  6
# Recorte 121 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 122 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 123 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 124 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 125 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 126 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 127 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 128 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 129 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 130 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 131 descartado por exceso de píxeles negros, blancos o vacíos
# Guardado recorte 132 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_132.tiff
# Guardado recorte 133 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_133.tiff
# Guardado recorte 134 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_134.tiff
# Guardado recorte 135 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_135.tiff
# Guardado recorte 136 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_136.tiff
# Guardado recorte 137 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_137.tiff
# Guardado recorte 138 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_138.tiff
# Guardado recorte 139 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_139.tiff
# Guardado recorte 140 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_140.tiff
# Fila nº  7
# Recorte 141 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 142 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 143 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 144 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 145 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 146 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 147 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 148 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 149 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 150 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 151 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 152 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 153 descartado por exceso de píxeles negros, blancos o vacíos
# Guardado recorte 154 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_154.tiff
# Guardado recorte 155 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_155.tiff
# Guardado recorte 156 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_156.tiff
# Guardado recorte 157 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_157.tiff
# Guardado recorte 158 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_158.tiff
# Guardado recorte 159 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_159.tiff
# Guardado recorte 160 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_160.tiff
# Fila nº  8
# Recorte 161 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 162 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 163 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 164 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 165 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 166 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 167 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 168 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 169 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 170 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 171 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 172 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 173 descartado por exceso de píxeles negros, blancos o vacíos
# Guardado recorte 174 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_174.tiff
# Guardado recorte 175 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_175.tiff
# Guardado recorte 176 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_176.tiff
# Guardado recorte 177 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_177.tiff
# Guardado recorte 178 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_178.tiff
# Guardado recorte 179 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_179.tiff
# Guardado recorte 180 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_180.tiff
# Fila nº  9
# Recorte 181 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 182 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 183 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 184 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 185 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 186 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 187 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 188 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 189 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 190 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 191 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 192 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 193 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 194 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 195 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 196 descartado por exceso de píxeles negros, blancos o vacíos
# Guardado recorte 197 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_197.tiff
# Guardado recorte 198 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_198.tiff
# Guardado recorte 199 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_199.tiff
# Guardado recorte 200 en cut_tiles\tiles_500x500_22/tile_22_subrecorte_200.tiff
# Fila nº  10
# Recorte 201 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 202 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 203 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 204 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 205 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 206 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 207 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 208 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 209 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 210 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 211 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 212 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 213 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 214 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 215 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 216 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 217 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 218 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 219 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 220 descartado por exceso de píxeles negros, blancos o vacíos
# Fila nº  11
# Recorte 221 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 222 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 223 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 224 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 225 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 226 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 227 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 228 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 229 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 230 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 231 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 232 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 233 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 234 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 235 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 236 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 237 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 238 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 239 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 240 descartado por exceso de píxeles negros, blancos o vacíos
# Fila nº  12
# Recorte 241 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 242 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 243 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 244 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 245 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 246 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 247 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 248 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 249 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 250 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 251 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 252 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 253 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 254 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 255 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 256 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 257 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 258 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 259 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 260 descartado por exceso de píxeles negros, blancos o vacíos
# Fila nº  13
# Recorte 261 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 262 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 263 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 264 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 265 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 266 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 267 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 268 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 269 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 270 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 271 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 272 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 273 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 274 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 275 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 276 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 277 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 278 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 279 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 280 descartado por exceso de píxeles negros, blancos o vacíos
# Fila nº  14
# Recorte 281 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 282 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 283 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 284 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 285 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 286 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 287 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 288 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 289 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 290 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 291 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 292 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 293 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 294 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 295 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 296 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 297 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 298 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 299 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 300 descartado por exceso de píxeles negros, blancos o vacíos
# Fila nº  15
# Recorte 301 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 302 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 303 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 304 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 305 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 306 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 307 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 308 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 309 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 310 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 311 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 312 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 313 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 314 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 315 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 316 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 317 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 318 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 319 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 320 descartado por exceso de píxeles negros, blancos o vacíos
# Fila nº  16
# Recorte 321 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 322 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 323 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 324 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 325 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 326 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 327 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 328 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 329 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 330 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 331 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 332 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 333 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 334 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 335 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 336 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 337 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 338 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 339 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 340 descartado por exceso de píxeles negros, blancos o vacíos
# Fila nº  17
# Recorte 341 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 342 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 343 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 344 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 345 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 346 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 347 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 348 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 349 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 350 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 351 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 352 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 353 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 354 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 355 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 356 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 357 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 358 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 359 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 360 descartado por exceso de píxeles negros, blancos o vacíos
# Fila nº  18
# Recorte 361 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 362 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 363 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 364 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 365 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 366 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 367 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 368 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 369 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 370 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 371 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 372 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 373 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 374 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 375 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 376 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 377 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 378 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 379 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 380 descartado por exceso de píxeles negros, blancos o vacíos
# Fila nº  19
# Recorte 381 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 382 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 383 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 384 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 385 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 386 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 387 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 388 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 389 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 390 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 391 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 392 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 393 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 394 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 395 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 396 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 397 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 398 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 399 descartado por exceso de píxeles negros, blancos o vacíos
# Recorte 400 descartado por exceso de píxeles negros, blancos o vacíos

# %% [markdown]
# ### Extracción de las coordenadas de cada tile
#
# Extraemos las coordenadas generales de cada tile y las filtramos.

# %%
csv_file = os.path.join(path, 'chinstraps_eca56.csv')
data = pd.read_csv(csv_file, encoding='ISO-8859-1')

print("Datos Originales: \n", data.head())

# Filtrar los puntos que están dentro del tile
filtered_data = data[
    (data['X'] >= min_x) & (data['X'] <= max_x) &
    (data['Y'] >= min_y) & (data['Y'] <= max_y)
]


filtered_data.to_csv(os.path.join('coords', 'coords_per_tile' ,f'coords_{NUM_TILE}.csv'), index=False)
filtered_data.head()
# Out:
# Datos Originales:
#     Id          X          Y
# 0   0 -59.209791 -62.285558
# 1   0 -59.209815 -62.285566
# 2   0 -59.209862 -62.285563
# 3   0 -59.209878 -62.285563
# 4   0 -59.209861 -62.285556
# Empty DataFrame
# Columns: [Id, X, Y]
# Index: []

# %% [markdown]
# ### Ejemplo de posibles resultados (para orientación)
#
# *IMAGEN 62*
#
# Esquina superior izquierda: (-59.236389267356785, -62.300974267474736)
#
# Esquina superior derecha: (-59.231134009926784, -62.300974267474736)
#
# Esquina inferior izquierda: (-59.236389267356785, -62.303714473634734)
#
# Esquina inferior derecha: (-59.231134009926784, -62.303714473634734)
#
# ---
#
# *IMAGEN 52*
#
# Esquina superior izquierda: (-59.236389267356785, -62.29823406131474)
#
# Esquina superior derecha: (-59.231134009926784, -62.29823406131474)
#
# Esquina inferior izquierda: (-59.236389267356785, -62.300974267474736)
#
# Esquina inferior derecha: (-59.231134009926784, -62.300974267474736)
