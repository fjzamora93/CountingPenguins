# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import rasterio
import numpy as np
from rasterio.transform import from_origin
from rasterio.windows import Window

# %% [markdown]
# ### Cargamos la imagen con rasterio
#
# Rasterio es la liberería que permitirá que las imágenes conserven los metadatos y que estén georeferenciadas aún después de procesarlas y recortarlas.

# %%
# path  = '/content/drive/My Drive/doctorado_albert/conteo_pinguinos/'
# image_name = "orthomosaic_all_big.tif"

NUM_TILE = 62

if os.path.exists('/content/drive/My Drive/doctorado_albert/conteo_pinguinos/'):
    path  = '/content/drive/My Drive/doctorado_albert/conteo_pinguinos/'
else:
    path = 'G:\\.shortcut-targets-by-id\\1pYgV5EIk4-LapLNhlCwpQaDAzuqNffXG\\doctorado_albert\\conteo_pinguinos'

image_name = f"recortes/recorte_{NUM_TILE}.tif"
tiff_file = os.path.join(path, image_name)


#! Verificamos la carga de la imagen (Solamente obtenemos información)
with rasterio.open(tiff_file) as src:
    print(f"Imagen cargada desde: {tiff_file}")
    print("Dimensiones: ", (src.width, src.height))
    print("Transformación de coordenadas: ", src.transform)
    print("Sistema de coordenadas: ", src.crs)
# Out:
# Imagen cargada desde: G:\.shortcut-targets-by-id\1pYgV5EIk4-LapLNhlCwpQaDAzuqNffXG\doctorado_albert\conteo_pinguinos\recortes/recorte_62.tif
# Dimensiones:  (10195, 11420)
# Transformación de coordenadas:  | 0.00, 0.00,-59.24|
# | 0.00,-0.00,-62.30|
# | 0.00, 0.00, 1.00|
# Sistema de coordenadas:  EPSG:4326

# %% [markdown]
# ### Obtención de las coordenadas y de variables necesarias de la imagen

# %%
with rasterio.open(tiff_file) as src:
    # Obtener los metadatos
    transform = src.transform
    metadata = src.meta
    top_left = src.transform * (0, 0)
    top_right = src.transform * (src.width, 0)
    bottom_left = src.transform * (0, src.height)
    bottom_right = src.transform * (src.width, src.height)

    WIDTH, HEIGHT = src.width, src.height

   
    print("Metadatos de la imagen:")
    for key, value in metadata.items():
        print(f"{key}: {value}")

    # También puedes acceder a información específica si lo deseas
    print("\nInformación adicional:")
    print("Ancho de la imagen:", src.width)
    print("Altura de la imagen:", src.height)
    print("Sistema de coordenadas:", src.crs)  # Sistema de referencia de coordenadas
    print("Transformación:", src.transform)  # Transformación espacial


    print("Coordenadas de las esquinas de la imagen:")
    print("TOP LEFT:", top_left)
    print("Esquina superior derecha:", top_right)
    print("Esquina inferior izquierda:", bottom_left)
    print("BOTTOM RIGHT:", bottom_right)
# Out:
# Metadatos de la imagen:
# driver: GTiff
# dtype: uint8
# nodata: None
# width: 10195
# height: 11420
# count: 4
# crs: EPSG:4326
# transform: | 0.00, 0.00,-59.24|
# | 0.00,-0.00,-62.30|
# | 0.00, 0.00, 1.00|
#
# Información adicional:
# Ancho de la imagen: 10195
# Altura de la imagen: 11420
# Sistema de coordenadas: EPSG:4326
# Transformación: | 0.00, 0.00,-59.24|
# | 0.00,-0.00,-62.30|
# | 0.00, 0.00, 1.00|
# Coordenadas de las esquinas de la imagen:
# TOP LEFT: (-59.236389267356785, -62.300974267474736)
# Esquina superior derecha: (-59.231134009926784, -62.300974267474736)
# Esquina inferior izquierda: (-59.236389267356785, -62.303714473634734)
# BOTTOM RIGHT: (-59.231134009926784, -62.303714473634734)

# %% [markdown]
# ## Definición de la carpeta de salida
#
# La carpeta de salida para las imágenes recortadas se llama 'cut_files', y aquí solamente estarán los tiles recortados en una aproximación de 500x500 (en realidad será un poco más, ya que el recorte de 20 filas y 20 columnas no es exacto).

# %%
#Directorio de salida
OUTPUT_DIR = os.path.join('cut_tiles', f'tiles_500x500_{NUM_TILE}')
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)
print(f"Output directory: {OUTPUT_DIR}")
# Out:
# Output directory: cut_tiles\tiles_500x500_62

# %% [markdown]
# ## Recorte de los tiles
#
# 1. Se define en cuánto se quiere recortar (en nuestro caso 20 filas y 20 columnas).
# 2. Se descartan todos los tiles que tengan una alta proporción de píxeles blanco o negros (mnás del 50%)
# 3. Acto seguido se procede al recorte y se envía a la carpeta de OUPUT_DIR.

# %%
import numpy as np
from rasterio.windows import Window

# Definición del recorte
ROWS, COLS = 20, 20

# Dimensiones de cada recorte
tile_width = WIDTH // COLS
tile_height = HEIGHT // ROWS

# Crear un directorio para las imágenes recortadas
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Abrir el TIFF original con rasterio
with rasterio.open(tiff_file) as src:
    for i in range(ROWS):
        print("Fila nº ", i)
        for j in range(COLS):
            left = j * tile_width
            upper = i * tile_height
            
            # Definir ventana de recorte
            window = Window(left, upper, tile_width, tile_height)
            
            # Leer el recorte
            cropped_image = src.read(window=window)

            # Identificar píxeles negros (000000)
            is_black = np.all(cropped_image == 0, axis=0)
            
            # Identificar píxeles blancos (FFFFFF)
            is_white = np.all(cropped_image == 255, axis=0)
            
            # Identificar píxeles vacíos o transparentes (suponiendo valor 0 en el canal de alfa o nodata)
            if "nodata" in src.profile:
                nodata_value = src.profile["nodata"]
                is_empty = np.any(cropped_image == nodata_value, axis=0)
            else:
                # Si hay un canal alfa, considera valores 0 como transparentes
                is_empty = cropped_image.shape[0] > 3 and np.all(cropped_image[-1] == 0, axis=0)

            # Calcular proporciones de píxeles negros, blancos y vacíos
            num_pixels = cropped_image.shape[1] * cropped_image.shape[2]  # Total de píxeles
            black_ratio = np.sum(is_black) / num_pixels
            white_ratio = np.sum(is_white) / num_pixels
            empty_ratio = np.sum(is_empty) / num_pixels

            # Guardar solo si todos los umbrales se cumplen
            if black_ratio <= 0.5 and white_ratio <= 0.1 and empty_ratio <= 0.1:
                # Crear los metadatos del recorte
                cropped_meta = src.meta.copy()
                cropped_meta.update({
                    "height": tile_height,
                    "width": tile_width,
                    "transform": rasterio.windows.transform(window, src.transform)
                })
                
                # Guardar la imagen recortada con georreferenciación
                output_path = f"{OUTPUT_DIR}/tile_{NUM_TILE}_subrecorte_{i * COLS + j + 1}.tiff"
                with rasterio.open(output_path, 'w', **cropped_meta) as dst:
                    dst.write(cropped_image)
                print(f"Guardado recorte {i * COLS + j + 1} en {output_path}")
            else:
                print(f"Recorte {i * COLS + j + 1} descartado por exceso de píxeles negros, blancos o vacíos")
# Out:
# Fila nº  0
# Guardado recorte 1 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_1.tiff
# Guardado recorte 2 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_2.tiff
# Guardado recorte 3 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_3.tiff
# Guardado recorte 4 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_4.tiff
# Guardado recorte 5 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_5.tiff
# Guardado recorte 6 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_6.tiff
# Guardado recorte 7 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_7.tiff
# Guardado recorte 8 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_8.tiff
# Guardado recorte 9 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_9.tiff
# Guardado recorte 10 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_10.tiff
# Guardado recorte 11 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_11.tiff
# Guardado recorte 12 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_12.tiff
# Guardado recorte 13 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_13.tiff
# Guardado recorte 14 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_14.tiff
# Guardado recorte 15 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_15.tiff
# Guardado recorte 16 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_16.tiff
# Guardado recorte 17 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_17.tiff
# Guardado recorte 18 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_18.tiff
# Guardado recorte 19 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_19.tiff
# Guardado recorte 20 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_20.tiff
# Fila nº  1
# Guardado recorte 21 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_21.tiff
# Guardado recorte 22 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_22.tiff
# Guardado recorte 23 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_23.tiff
# Guardado recorte 24 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_24.tiff
# Guardado recorte 25 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_25.tiff
# Guardado recorte 26 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_26.tiff
# Guardado recorte 27 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_27.tiff
# Guardado recorte 28 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_28.tiff
# Guardado recorte 29 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_29.tiff
# Guardado recorte 30 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_30.tiff
# Guardado recorte 31 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_31.tiff
# Guardado recorte 32 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_32.tiff
# Guardado recorte 33 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_33.tiff
# Guardado recorte 34 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_34.tiff
# Guardado recorte 35 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_35.tiff
# Guardado recorte 36 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_36.tiff
# Guardado recorte 37 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_37.tiff
# Guardado recorte 38 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_38.tiff
# Guardado recorte 39 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_39.tiff
# Guardado recorte 40 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_40.tiff
# Fila nº  2
# Guardado recorte 41 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_41.tiff
# Guardado recorte 42 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_42.tiff
# Guardado recorte 43 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_43.tiff
# Guardado recorte 44 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_44.tiff
# Guardado recorte 45 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_45.tiff
# Guardado recorte 46 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_46.tiff
# Guardado recorte 47 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_47.tiff
# Guardado recorte 48 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_48.tiff
# Guardado recorte 49 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_49.tiff
# Guardado recorte 50 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_50.tiff
# Guardado recorte 51 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_51.tiff
# Guardado recorte 52 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_52.tiff
# Guardado recorte 53 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_53.tiff
# Guardado recorte 54 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_54.tiff
# Guardado recorte 55 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_55.tiff
# Guardado recorte 56 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_56.tiff
# Guardado recorte 57 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_57.tiff
# Guardado recorte 58 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_58.tiff
# Guardado recorte 59 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_59.tiff
# Guardado recorte 60 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_60.tiff
# Fila nº  3
# Guardado recorte 61 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_61.tiff
# Guardado recorte 62 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_62.tiff
# Guardado recorte 63 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_63.tiff
# Guardado recorte 64 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_64.tiff
# Guardado recorte 65 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_65.tiff
# Guardado recorte 66 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_66.tiff
# Guardado recorte 67 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_67.tiff
# Guardado recorte 68 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_68.tiff
# Guardado recorte 69 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_69.tiff
# Guardado recorte 70 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_70.tiff
# Guardado recorte 71 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_71.tiff
# Guardado recorte 72 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_72.tiff
# Guardado recorte 73 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_73.tiff
# Guardado recorte 74 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_74.tiff
# Guardado recorte 75 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_75.tiff
# Guardado recorte 76 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_76.tiff
# Guardado recorte 77 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_77.tiff
# Guardado recorte 78 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_78.tiff
# Guardado recorte 79 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_79.tiff
# Guardado recorte 80 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_80.tiff
# Fila nº  4
# Guardado recorte 81 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_81.tiff
# Guardado recorte 82 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_82.tiff
# Guardado recorte 83 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_83.tiff
# Guardado recorte 84 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_84.tiff
# Guardado recorte 85 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_85.tiff
# Guardado recorte 86 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_86.tiff
# Guardado recorte 87 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_87.tiff
# Guardado recorte 88 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_88.tiff
# Guardado recorte 89 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_89.tiff
# Guardado recorte 90 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_90.tiff
# Guardado recorte 91 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_91.tiff
# Guardado recorte 92 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_92.tiff
# Guardado recorte 93 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_93.tiff
# Guardado recorte 94 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_94.tiff
# Guardado recorte 95 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_95.tiff
# Guardado recorte 96 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_96.tiff
# Guardado recorte 97 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_97.tiff
# Guardado recorte 98 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_98.tiff
# Guardado recorte 99 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_99.tiff
# Guardado recorte 100 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_100.tiff
# Fila nº  5
# Guardado recorte 101 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_101.tiff
# Guardado recorte 102 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_102.tiff
# Guardado recorte 103 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_103.tiff
# Guardado recorte 104 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_104.tiff
# Guardado recorte 105 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_105.tiff
# Guardado recorte 106 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_106.tiff
# Guardado recorte 107 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_107.tiff
# Guardado recorte 108 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_108.tiff
# Guardado recorte 109 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_109.tiff
# Guardado recorte 110 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_110.tiff
# Guardado recorte 111 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_111.tiff
# Guardado recorte 112 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_112.tiff
# Guardado recorte 113 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_113.tiff
# Guardado recorte 114 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_114.tiff
# Guardado recorte 115 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_115.tiff
# Guardado recorte 116 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_116.tiff
# Guardado recorte 117 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_117.tiff
# Guardado recorte 118 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_118.tiff
# Guardado recorte 119 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_119.tiff
# Guardado recorte 120 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_120.tiff
# Fila nº  6
# Guardado recorte 121 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_121.tiff
# Guardado recorte 122 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_122.tiff
# Guardado recorte 123 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_123.tiff
# Guardado recorte 124 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_124.tiff
# Guardado recorte 125 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_125.tiff
# Guardado recorte 126 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_126.tiff
# Guardado recorte 127 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_127.tiff
# Guardado recorte 128 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_128.tiff
# Guardado recorte 129 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_129.tiff
# Guardado recorte 130 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_130.tiff
# Guardado recorte 131 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_131.tiff
# Guardado recorte 132 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_132.tiff
# Guardado recorte 133 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_133.tiff
# Guardado recorte 134 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_134.tiff
# Guardado recorte 135 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_135.tiff
# Guardado recorte 136 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_136.tiff
# Guardado recorte 137 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_137.tiff
# Guardado recorte 138 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_138.tiff
# Guardado recorte 139 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_139.tiff
# Guardado recorte 140 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_140.tiff
# Fila nº  7
# Guardado recorte 141 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_141.tiff
# Guardado recorte 142 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_142.tiff
# Guardado recorte 143 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_143.tiff
# Guardado recorte 144 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_144.tiff
# Guardado recorte 145 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_145.tiff
# Guardado recorte 146 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_146.tiff
# Guardado recorte 147 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_147.tiff
# Guardado recorte 148 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_148.tiff
# Guardado recorte 149 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_149.tiff
# Guardado recorte 150 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_150.tiff
# Guardado recorte 151 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_151.tiff
# Guardado recorte 152 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_152.tiff
# Guardado recorte 153 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_153.tiff
# Guardado recorte 154 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_154.tiff
# Guardado recorte 155 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_155.tiff
# Guardado recorte 156 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_156.tiff
# Guardado recorte 157 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_157.tiff
# Guardado recorte 158 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_158.tiff
# Guardado recorte 159 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_159.tiff
# Guardado recorte 160 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_160.tiff
# Fila nº  8
# Guardado recorte 161 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_161.tiff
# Guardado recorte 162 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_162.tiff
# Guardado recorte 163 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_163.tiff
# Guardado recorte 164 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_164.tiff
# Guardado recorte 165 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_165.tiff
# Guardado recorte 166 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_166.tiff
# Guardado recorte 167 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_167.tiff
# Guardado recorte 168 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_168.tiff
# Guardado recorte 169 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_169.tiff
# Guardado recorte 170 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_170.tiff
# Guardado recorte 171 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_171.tiff
# Guardado recorte 172 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_172.tiff
# Guardado recorte 173 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_173.tiff
# Guardado recorte 174 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_174.tiff
# Guardado recorte 175 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_175.tiff
# Guardado recorte 176 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_176.tiff
# Guardado recorte 177 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_177.tiff
# Guardado recorte 178 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_178.tiff
# Guardado recorte 179 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_179.tiff
# Guardado recorte 180 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_180.tiff
# Fila nº  9
# Guardado recorte 181 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_181.tiff
# Guardado recorte 182 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_182.tiff
# Guardado recorte 183 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_183.tiff
# Guardado recorte 184 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_184.tiff
# Guardado recorte 185 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_185.tiff
# Guardado recorte 186 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_186.tiff
# Guardado recorte 187 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_187.tiff
# Guardado recorte 188 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_188.tiff
# Guardado recorte 189 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_189.tiff
# Guardado recorte 190 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_190.tiff
# Guardado recorte 191 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_191.tiff
# Guardado recorte 192 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_192.tiff
# Guardado recorte 193 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_193.tiff
# Guardado recorte 194 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_194.tiff
# Guardado recorte 195 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_195.tiff
# Guardado recorte 196 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_196.tiff
# Guardado recorte 197 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_197.tiff
# Guardado recorte 198 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_198.tiff
# Guardado recorte 199 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_199.tiff
# Guardado recorte 200 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_200.tiff
# Fila nº  10
# Guardado recorte 201 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_201.tiff
# Guardado recorte 202 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_202.tiff
# Guardado recorte 203 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_203.tiff
# Guardado recorte 204 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_204.tiff
# Guardado recorte 205 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_205.tiff
# Guardado recorte 206 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_206.tiff
# Guardado recorte 207 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_207.tiff
# Guardado recorte 208 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_208.tiff
# Guardado recorte 209 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_209.tiff
# Guardado recorte 210 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_210.tiff
# Guardado recorte 211 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_211.tiff
# Guardado recorte 212 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_212.tiff
# Guardado recorte 213 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_213.tiff
# Guardado recorte 214 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_214.tiff
# Guardado recorte 215 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_215.tiff
# Guardado recorte 216 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_216.tiff
# Guardado recorte 217 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_217.tiff
# Guardado recorte 218 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_218.tiff
# Guardado recorte 219 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_219.tiff
# Guardado recorte 220 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_220.tiff
# Fila nº  11
# Guardado recorte 221 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_221.tiff
# Guardado recorte 222 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_222.tiff
# Guardado recorte 223 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_223.tiff
# Guardado recorte 224 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_224.tiff
# Guardado recorte 225 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_225.tiff
# Guardado recorte 226 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_226.tiff
# Guardado recorte 227 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_227.tiff
# Guardado recorte 228 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_228.tiff
# Guardado recorte 229 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_229.tiff
# Guardado recorte 230 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_230.tiff
# Guardado recorte 231 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_231.tiff
# Guardado recorte 232 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_232.tiff
# Guardado recorte 233 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_233.tiff
# Guardado recorte 234 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_234.tiff
# Guardado recorte 235 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_235.tiff
# Guardado recorte 236 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_236.tiff
# Guardado recorte 237 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_237.tiff
# Guardado recorte 238 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_238.tiff
# Guardado recorte 239 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_239.tiff
# Guardado recorte 240 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_240.tiff
# Fila nº  12
# Guardado recorte 241 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_241.tiff
# Guardado recorte 242 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_242.tiff
# Guardado recorte 243 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_243.tiff
# Guardado recorte 244 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_244.tiff
# Guardado recorte 245 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_245.tiff
# Guardado recorte 246 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_246.tiff
# Guardado recorte 247 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_247.tiff
# Guardado recorte 248 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_248.tiff
# Guardado recorte 249 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_249.tiff
# Guardado recorte 250 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_250.tiff
# Guardado recorte 251 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_251.tiff
# Guardado recorte 252 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_252.tiff
# Guardado recorte 253 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_253.tiff
# Guardado recorte 254 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_254.tiff
# Guardado recorte 255 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_255.tiff
# Guardado recorte 256 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_256.tiff
# Guardado recorte 257 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_257.tiff
# Guardado recorte 258 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_258.tiff
# Guardado recorte 259 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_259.tiff
# Guardado recorte 260 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_260.tiff
# Fila nº  13
# Guardado recorte 261 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_261.tiff
# Guardado recorte 262 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_262.tiff
# Guardado recorte 263 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_263.tiff
# Guardado recorte 264 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_264.tiff
# Guardado recorte 265 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_265.tiff
# Guardado recorte 266 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_266.tiff
# Guardado recorte 267 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_267.tiff
# Guardado recorte 268 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_268.tiff
# Guardado recorte 269 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_269.tiff
# Guardado recorte 270 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_270.tiff
# Guardado recorte 271 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_271.tiff
# Guardado recorte 272 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_272.tiff
# Guardado recorte 273 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_273.tiff
# Guardado recorte 274 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_274.tiff
# Guardado recorte 275 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_275.tiff
# Guardado recorte 276 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_276.tiff
# Guardado recorte 277 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_277.tiff
# Guardado recorte 278 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_278.tiff
# Guardado recorte 279 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_279.tiff
# Guardado recorte 280 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_280.tiff
# Fila nº  14
# Guardado recorte 281 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_281.tiff
# Guardado recorte 282 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_282.tiff
# Guardado recorte 283 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_283.tiff
# Guardado recorte 284 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_284.tiff
# Guardado recorte 285 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_285.tiff
# Guardado recorte 286 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_286.tiff
# Guardado recorte 287 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_287.tiff
# Guardado recorte 288 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_288.tiff
# Guardado recorte 289 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_289.tiff
# Guardado recorte 290 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_290.tiff
# Guardado recorte 291 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_291.tiff
# Guardado recorte 292 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_292.tiff
# Guardado recorte 293 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_293.tiff
# Guardado recorte 294 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_294.tiff
# Guardado recorte 295 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_295.tiff
# Guardado recorte 296 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_296.tiff
# Guardado recorte 297 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_297.tiff
# Guardado recorte 298 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_298.tiff
# Guardado recorte 299 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_299.tiff
# Guardado recorte 300 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_300.tiff
# Fila nº  15
# Guardado recorte 301 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_301.tiff
# Guardado recorte 302 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_302.tiff
# Guardado recorte 303 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_303.tiff
# Guardado recorte 304 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_304.tiff
# Guardado recorte 305 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_305.tiff
# Guardado recorte 306 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_306.tiff
# Guardado recorte 307 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_307.tiff
# Guardado recorte 308 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_308.tiff
# Guardado recorte 309 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_309.tiff
# Guardado recorte 310 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_310.tiff
# Guardado recorte 311 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_311.tiff
# Guardado recorte 312 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_312.tiff
# Guardado recorte 313 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_313.tiff
# Guardado recorte 314 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_314.tiff
# Guardado recorte 315 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_315.tiff
# Guardado recorte 316 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_316.tiff
# Guardado recorte 317 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_317.tiff
# Guardado recorte 318 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_318.tiff
# Guardado recorte 319 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_319.tiff
# Guardado recorte 320 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_320.tiff
# Fila nº  16
# Guardado recorte 321 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_321.tiff
# Guardado recorte 322 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_322.tiff
# Guardado recorte 323 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_323.tiff
# Guardado recorte 324 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_324.tiff
# Guardado recorte 325 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_325.tiff
# Guardado recorte 326 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_326.tiff
# Guardado recorte 327 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_327.tiff
# Guardado recorte 328 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_328.tiff
# Guardado recorte 329 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_329.tiff
# Guardado recorte 330 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_330.tiff
# Guardado recorte 331 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_331.tiff
# Guardado recorte 332 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_332.tiff
# Guardado recorte 333 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_333.tiff
# Guardado recorte 334 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_334.tiff
# Guardado recorte 335 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_335.tiff
# Guardado recorte 336 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_336.tiff
# Guardado recorte 337 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_337.tiff
# Guardado recorte 338 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_338.tiff
# Guardado recorte 339 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_339.tiff
# Guardado recorte 340 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_340.tiff
# Fila nº  17
# Guardado recorte 341 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_341.tiff
# Guardado recorte 342 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_342.tiff
# Guardado recorte 343 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_343.tiff
# Guardado recorte 344 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_344.tiff
# Guardado recorte 345 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_345.tiff
# Guardado recorte 346 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_346.tiff
# Guardado recorte 347 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_347.tiff
# Guardado recorte 348 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_348.tiff
# Guardado recorte 349 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_349.tiff
# Guardado recorte 350 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_350.tiff
# Guardado recorte 351 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_351.tiff
# Guardado recorte 352 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_352.tiff
# Guardado recorte 353 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_353.tiff
# Guardado recorte 354 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_354.tiff
# Guardado recorte 355 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_355.tiff
# Guardado recorte 356 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_356.tiff
# Guardado recorte 357 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_357.tiff
# Guardado recorte 358 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_358.tiff
# Guardado recorte 359 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_359.tiff
# Guardado recorte 360 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_360.tiff
# Fila nº  18
# Guardado recorte 361 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_361.tiff
# Guardado recorte 362 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_362.tiff
# Guardado recorte 363 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_363.tiff
# Guardado recorte 364 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_364.tiff
# Guardado recorte 365 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_365.tiff
# Guardado recorte 366 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_366.tiff
# Guardado recorte 367 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_367.tiff
# Guardado recorte 368 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_368.tiff
# Guardado recorte 369 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_369.tiff
# Guardado recorte 370 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_370.tiff
# Guardado recorte 371 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_371.tiff
# Guardado recorte 372 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_372.tiff
# Guardado recorte 373 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_373.tiff
# Guardado recorte 374 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_374.tiff
# Guardado recorte 375 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_375.tiff
# Guardado recorte 376 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_376.tiff
# Guardado recorte 377 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_377.tiff
# Guardado recorte 378 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_378.tiff
# Guardado recorte 379 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_379.tiff
# Guardado recorte 380 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_380.tiff
# Fila nº  19
# Guardado recorte 381 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_381.tiff
# Guardado recorte 382 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_382.tiff
# Guardado recorte 383 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_383.tiff
# Guardado recorte 384 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_384.tiff
# Guardado recorte 385 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_385.tiff
# Guardado recorte 386 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_386.tiff
# Guardado recorte 387 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_387.tiff
# Guardado recorte 388 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_388.tiff
# Guardado recorte 389 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_389.tiff
# Guardado recorte 390 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_390.tiff
# Guardado recorte 391 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_391.tiff
# Guardado recorte 392 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_392.tiff
# Guardado recorte 393 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_393.tiff
# Guardado recorte 394 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_394.tiff
# Guardado recorte 395 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_395.tiff
# Guardado recorte 396 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_396.tiff
# Guardado recorte 397 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_397.tiff
# Guardado recorte 398 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_398.tiff
# Guardado recorte 399 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_399.tiff
# Guardado recorte 400 en cut_tiles\tiles_500x500_62/tile_62_subrecorte_400.tiff

# %% [markdown]
# ### Comprobamos que los recortes están efectivamente georeferenciados
#
# El código que hay a continuación solamente verifica que la georeferencia es correcta

# %%
TEST_TILE = os.path.join(f'tile_{NUM_TILE}_subrecorte_{NUM_TILE}.tiff')
sample_file = os.path.join(OUTPUT_DIR, TEST_TILE)

with rasterio.open(sample_file) as src:
    transform = src.transform
    metadata = src.meta
    top_left = src.transform * (0, 0)
    top_right = src.transform * (src.width, 0)
    bottom_left = src.transform * (0, src.height)
    bottom_right = src.transform * (src.width, src.height)

    WIDTH, HEIGHT = src.width, src.height

   
    print(f"Metadatos de la imagen {sample_file}:")
    for key, value in metadata.items():
        print(f"{key}: {value}")

    # También puedes acceder a información específica si lo deseas
    print("\nInformación adicional:")
    print("Ancho de la imagen:", src.width)
    print("Altura de la imagen:", src.height)
    print("Sistema de coordenadas:", src.crs)  # Sistema de referencia de coordenadas
    print("Transformación:", src.transform)  # Transformación espacial


    print("Coordenadas de las esquinas de la imagen:")
    print("TOP LEFT:", top_left)
    print("Esquina superior derecha:", top_right)
    print("Esquina inferior izquierda:", bottom_left)
    print("BOTTOM RIGHT:", bottom_right)
# Out:
# Metadatos de la imagen cut_tiles\tiles_500x500_62\tile_62_subrecorte_62.tiff:
# driver: GTiff
# dtype: uint8
# nodata: None
# width: 509
# height: 571
# count: 4
# crs: EPSG:4326
# transform: | 0.00, 0.00,-59.24|
# | 0.00,-0.00,-62.30|
# | 0.00, 0.00, 1.00|
#
# Información adicional:
# Ancho de la imagen: 509
# Altura de la imagen: 571
# Sistema de coordenadas: EPSG:4326
# Transformación: | 0.00, 0.00,-59.24|
# | 0.00,-0.00,-62.30|
# | 0.00, 0.00, 1.00|
# Coordenadas de las esquinas de la imagen:
# TOP LEFT: (-59.236126891090784, -62.301385298398735)
# Esquina superior derecha: (-59.23586451482478, -62.301385298398735)
# Esquina inferior izquierda: (-59.236126891090784, -62.30152230870674)
# BOTTOM RIGHT: (-59.23586451482478, -62.30152230870674)
